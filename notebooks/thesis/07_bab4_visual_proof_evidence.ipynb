# %% [markdown]
# # BAB IV Visual Proof Evidence
#
# Notebook ini adalah indeks bukti visual untuk BAB IV. Semua gambar
# dibangun dari artifact runtime, benchmark CSV/JSON, atau source code
# proyek SCPA. Bagian yang belum memenuhi syarat generalisasi diberi
# status blocker, bukan dipaksakan menjadi klaim.

# %%
from pathlib import Path
import json

run_dir = Path(r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_visual_proof_20260616_231552")
manifest = json.loads((run_dir / "manifest.json").read_text(encoding="utf-8"))
manifest["status"]

# %% [markdown]
# ## Dashboard evidence runtime dan benchmark

# %%
from IPython.display import Image, display
display(Image(filename=r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_visual_proof_20260616_231552\plots\evidence_dashboard.png"))

# %% [markdown]
# ## Rincian teknis SBERT

# %%
from IPython.display import Image, display
display(Image(filename=r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_visual_proof_20260616_231552\plots\sbert_technical_evidence_card.png"))

# %% [markdown]
# ## Rincian teknis NCF

# %%
from IPython.display import Image, display
display(Image(filename=r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_visual_proof_20260616_231552\plots\ncf_technical_evidence_card.png"))

# %% [markdown]
# ## Rincian teknis DQN

# %%
from IPython.display import Image, display
display(Image(filename=r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_visual_proof_20260616_231552\plots\dqn_technical_evidence_card.png"))

# %% [markdown]
# ## Rincian hybrid dan batas klaim

# %%
from IPython.display import Image, display
display(Image(filename=r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_visual_proof_20260616_231552\plots\hybrid_claim_evidence_card.png"))

# %% [markdown]
# ## Status capture frontend saat revisi

# %%
from IPython.display import Image, display
display(Image(filename=r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_visual_proof_20260616_231552\terminal\powershell_current_capture_status.png"))

# %% [markdown]
# ## Plot ablation NDCG@10

# %%
from IPython.display import Image, display
display(Image(filename=r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_visual_proof_20260616_231552\plots\ablation_ndcg10.png"))

# %% [markdown]
# ## Histogram delta DQN

# %%
from IPython.display import Image, display
display(Image(filename=r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_visual_proof_20260616_231552\plots\dqn_session_delta_ndcg.png"))

# %% [markdown]
# ## Status gold qrels

# %%
from IPython.display import Image, display
display(Image(filename=r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_visual_proof_20260616_231552\plots\qrels_status.png"))
