# %% [markdown]
# # BAB IV Benchmark Frozen Split dan Ablation
#
# Notebook ini menampilkan evidence utama untuk melengkapi bagian evaluasi
# benchmark BAB IV: frozen split, ablation SBERT/NCF/DQN hybrid, stability
# DQN, dan status gold qrels SBERT. Semua angka berasal dari artifact repo,
# bukan tabel manual.

# %%
from pathlib import Path
import json
import pandas as pd

run_dir = Path(r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_benchmark_evidence_20260616_223845")
manifest = json.loads((run_dir / "manifest.json").read_text(encoding="utf-8"))
manifest["status"]

# %% [markdown]
# ## 1. Status Split Eksperimen

# %%
from IPython.display import Image, display
display(Image(filename=r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_benchmark_evidence_20260616_223845\plots\split_status_matrix.png"))

# %% [markdown]
# ## 2. Frozen Split Manifest

# %%
display(Image(filename=r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_benchmark_evidence_20260616_223845\plots\split_counts.png"))

# %% [markdown]
# ## 3. Ablation NDCG@10

# %%
display(Image(filename=r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_benchmark_evidence_20260616_223845\plots\ablation_ndcg10.png"))

# %% [markdown]
# ## 4. DQN Stability Multi Seed

# %%
display(Image(filename=r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_benchmark_evidence_20260616_223845\plots\dqn_stability.png"))

# %% [markdown]
# ## 5. DQN Held-Out Session Rerank Proxy

# %%
display(Image(filename=r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_benchmark_evidence_20260616_223845\plots\dqn_session_delta_ndcg.png"))

# %%
display(Image(filename=r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_benchmark_evidence_20260616_223845\plots\dqn_rank_delta_examples.png"))

# %% [markdown]
# ## 6. Status Gold Qrels SBERT

# %%
display(Image(filename=r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_benchmark_evidence_20260616_223845\plots\qrels_status.png"))

# %% [markdown]
# ## 7. Bukti Command

# %%
display(Image(filename=r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_benchmark_evidence_20260616_223845\terminal\terminal_thesis_benchmark.png"))

# %%
display(Image(filename=r"E:\TUGAS AKHIR\SCPA\reports\thesis_evidence\bab4_benchmark_evidence_20260616_223845\terminal\terminal_gold_qrels.png"))
